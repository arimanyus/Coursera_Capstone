# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera
# ### Vivek Tiwari
#
# This Jupyter Notebook contains all the code and brief comments of the Coursera Capstone project.

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Datasets](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction <a name="introduction"></a>
#
# People are extra-cautious about which restaurant they want to visit as the pandemic has made hygiene a fundamental point in our lives. We find out the best, most hygienic restaurants in San Francisco neighbourhoods in our today's project.

# %% [markdown]
# ## Datasets <a name="data"></a>
#
# 1. The first dataset to be used consists of a **GeoJSON file with the names and boundaries of 41 San Francisco neighborhoods (GeoJSON)**
# 2. **Foursquare APIs (URI)**
# 3. City of San Francisco Health Department’s **hygiene inspection program (CSV)**

# %%
pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: requests>=2.20.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from sodapy) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2019.11.28)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fuzzy_pandas
# Out:
# Requirement already satisfied: fuzzy_pandas in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (0.1)
# Requirement already satisfied: pandas in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from fuzzy_pandas) (1.0.1)
# Requirement already satisfied: csvmatch in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from fuzzy_pandas) (1.20)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from pandas->fuzzy_pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from pandas->fuzzy_pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from pandas->fuzzy_pandas) (1.18.1)
# Requirement already satisfied: chardet==3.0.4 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (3.0.4)
# Requirement already satisfied: doublemetaphone==0.1 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (0.1)
# Requirement already satisfied: jellyfish==0.7.2 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (0.7.2)
# Requirement already satisfied: tqdm==4.18.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (4.18.0)
# Requirement already satisfied: unidecode==1.1.1 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (1.1.1)
# Requirement already satisfied: colorama==0.4.3 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (0.4.3)
# Requirement already satisfied: dedupe==1.10.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from csvmatch->fuzzy_pandas) (1.10.0)
# Requirement already satisfied: six>=1.5 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->fuzzy_pandas) (1.14.0)
# Requirement already satisfied: dedupe-hcluster in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.3.8)
# Requirement already satisfied: BTrees>=4.1.4 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (4.7.2)
# Requirement already satisfied: highered>=0.2.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.2.1)
# Requirement already satisfied: dedupe-variable-datetime in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.1.5)
# Requirement already satisfied: affinegap>=1.3 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.11)
# Requirement already satisfied: categorical-distance>=1.9 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.9)
# Requirement already satisfied: zope.index in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (5.0.0)
# Requirement already satisfied: simplecosine>=1.2 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.2)
# Requirement already satisfied: haversine>=0.4.1 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (2.2.0)
# Requirement already satisfied: fastcluster in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.1.26)
# Requirement already satisfied: rlr>=2.4.3 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (2.4.5)
# Requirement already satisfied: Levenshtein-search in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.4.5)
# Requirement already satisfied: persistent>=4.1.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from BTrees>=4.1.4->dedupe==1.10.0->csvmatch->fuzzy_pandas) (4.6.4)
# Requirement already satisfied: zope.interface in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from BTrees>=4.1.4->dedupe==1.10.0->csvmatch->fuzzy_pandas) (5.1.0)
# Requirement already satisfied: pyhacrf-datamade>=0.2.0 in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from highered>=0.2.0->dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.2.5)
# Requirement already satisfied: future in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe-variable-datetime->dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.18.2)
# Requirement already satisfied: datetime-distance in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from dedupe-variable-datetime->dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.1.3)
# Requirement already satisfied: setuptools in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from zope.index->dedupe==1.10.0->csvmatch->fuzzy_pandas) (46.0.0.post20200309)
# Requirement already satisfied: pylbfgs in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from rlr>=2.4.3->dedupe==1.10.0->csvmatch->fuzzy_pandas) (0.2.0.13)
# Requirement already satisfied: cffi; platform_python_implementation == "CPython" in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from persistent>=4.1.0->BTrees>=4.1.4->dedupe==1.10.0->csvmatch->fuzzy_pandas) (1.14.0)
# Requirement already satisfied: pycparser in /Users/Matias/opt/anaconda3/lib/python3.7/site-packages (from cffi; platform_python_implementation == "CPython"->persistent>=4.1.0->BTrees>=4.1.4->dedupe==1.10.0->csvmatch->fuzzy_pandas) (2.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import requests
import folium
import fuzzy_pandas as fpd
from sodapy import Socrata

# %% [markdown]
# <h3> Importinge the Datasets <h3>
#
# The neighborhoods and hygiene inspection datasets are easily accessible thanks to the Socrata API provided by the San Francisco Government

# %%
client = Socrata("data.sfgov.org", None)
results = client.get("pyih-qa8i", limit=60000)
hygiene_df=pd.DataFrame.from_records(results)

nhoods=client.get("743h-p4bq", limit=60000) # We will use this JSON file later on to map out San Francisco's neighborhoods
nhoods_df=pd.DataFrame.from_records(nhoods)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
print(hygiene_df.shape)
print(nhoods_df.shape)
# Out:
# (53973, 23)
# (92, 4)

# %%
hygiene_df.head()
# Out:
#   business_id          business_name          business_address  business_city  \
# 0      101192           Cochinita #2  2 Marina Blvd Fort Mason  San Francisco
# 1       97975             BREADBELLY           1408 Clement St  San Francisco
# 2       92982  Great Gold Restaurant             3161 24th St.  San Francisco
# 3      101389                 HOMAGE         214 CALIFORNIA ST  San Francisco
# 4       85986           Pronto Pizza               798 Eddy St  San Francisco
#
#   business_state business_phone_number    inspection_id  \
# 0             CA          +14150429222  101192_20190606
# 1             CA          +14157240859   97975_20190725
# 2             CA                   NaN   92982_20170912
# 3             CA          +14154878161  101389_20190625
# 4             CA                   NaN   85986_20161011
#
#            inspection_date        inspection_type business_postal_code  ...  \
# 0  2019-06-06T00:00:00.000          New Ownership                  NaN  ...
# 1  2019-07-25T00:00:00.000  Routine - Unscheduled                94118  ...
# 2  2017-09-12T00:00:00.000          New Ownership                94110  ...
# 3  2019-06-25T00:00:00.000       New Construction                94111  ...
# 4  2016-10-11T00:00:00.000          New Ownership                94109  ...
#
#    risk_category business_latitude business_longitude business_location  \
# 0            NaN               NaN                NaN               NaN
# 1  Moderate Risk               NaN                NaN               NaN
# 2            NaN               NaN                NaN               NaN
# 3            NaN               NaN                NaN               NaN
# 4      High Risk               NaN                NaN               NaN
#
#   :@computed_region_fyvs_ahh9 :@computed_region_p5aj_wyqh  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_rxqg_mtj9 :@computed_region_yftq_j783  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_bh8s_q3mv :@computed_region_ajp5_b2md
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# We will now use the Foursquare API to search each neighborhoods restaurants

# %%
client_id = 'U0BHFR2CGBOER0NS2E3LDULEVT032SXA3KVWLR2U1RTQBJCV' # your Foursquare ID
client_secret = 'WRRQIHUGH45BSIKD4HCNE5ZXRNAK3E1JJNIXVNRVBNYLZYEC' # your Foursquare Secret
version = '20180605' # Foursquare API version
category= '4d4b7105d754a06374d81259' #Food Category
limit=1000


print('Your credentails:')
print('CLIENT_ID: ' + client_id)
print('CLIENT_SECRET:' + client_secret)
# Out:
# Your credentails:
# CLIENT_ID: U0BHFR2CGBOER0NS2E3LDULEVT032SXA3KVWLR2U1RTQBJCV
# CLIENT_SECRET:WRRQIHUGH45BSIKD4HCNE5ZXRNAK3E1JJNIXVNRVBNYLZYEC

# %%
def getVenuesLoc(names, radius=600):
    
    venues_list=[]
    unexplored_nhoods=[]
    explored_nhoods=[]
    for name in names:
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&near={},San Francisco, CA&categoryId={}&radius={}&limit={}'.format(
        client_id,
        client_secret,
        version,
        name,
        category,
        radius, 
        limit)
            
        # make the GET request for neighbourhoods that don't throw error
        results = requests.get(url).json()
        if 'errorType' in results['meta']:
            print("Couldn't get venues from:", name)
            unexplored_nhoods.append(name)
        else:
            print(name)
            explored_nhoods.append(name)
            results = results["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
            venues_list.append([(
            name,
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
            nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
            nearby_venues.columns = ['Neighbourhood', 
                  'Venue', 
                  'Venue_Latitude', 
                  'Venue_Longitude', 
                  'Venue_Category']
    
    return(nearby_venues, explored_nhoods, unexplored_nhoods)

# %% [markdown]
# Becuase there are certain neighborhoods grouped, we ungroup them to apply the function

# %%
nhood_names=[]
for name in nhoods_df['nbrhood']:
    if '/' in name:
        split_name=name.split('/',1)
        nhood_names.append(split_name[0].strip())
        nhood_names.append(split_name[1].strip())
    elif '/' not in name:
        nhood_names.append(name)

# %%
sf_venues, explored_nhoods, unexplored_nhoods = getVenuesLoc(nhood_names)
# Out:
# Alamo Square
# Anza Vista
# Balboa Terrace
# Couldn't get venues from: Bayview
# Bernal Heights
# Buena Vista Park
# Ashbury Heights
# Couldn't get venues from: Central Richmond
# Central Sunset
# Clarendon Heights
# Couldn't get venues from: Corona Heights
# Cow Hollow
# Crocker Amazon
# Couldn't get venues from: Diamond Heights
# Downtown
# Duboce Triangle
# Couldn't get venues from: Eureka Valley
# Couldn't get venues from: Dolores Heights
# Excelsior
# Financial District
# Couldn't get venues from: Barbary Coast
# Couldn't get venues from: Yerba Buena
# Forest Hill
# Couldn't get venues from: Forest Hills Extension
# Forest Knolls
# Glen Park
# Golden Gate Heights
# Golden Gate Park
# Haight Ashbury
# Hayes Valley
# Hunters Point
# Ingleside
# Ingleside Heights
# Ingleside Terrace
# Couldn't get venues from: Inner Mission
# Inner Parkside
# Couldn't get venues from: Inner Richmond
# Inner Sunset
# Jordan Park
# Laurel Heights
# Couldn't get venues from: Lake Street
# Monterey Heights
# Couldn't get venues from: Lake Shore
# Lakeside
# Lone Mountain
# Lower Pacific Heights
# Couldn't get venues from: Marina
# Merced Heights
# Merced Manor
# Couldn't get venues from: Midtown Terrace
# South Beach
# Miraloma Park
# Mission Bay
# Mission Dolores
# Mission Terrace
# Mount Davidson Manor
# Noe Valley
# North Beach
# Couldn't get venues from: North Panhandle
# Couldn't get venues from: North Waterfront
# Oceanview
# Outer Mission
# Couldn't get venues from: Outer Parkside
# Couldn't get venues from: Outer Richmond
# Outer Sunset
# Pacific Heights
# Couldn't get venues from: Parkside
# Cole Valley
# Couldn't get venues from: Parnassus Heights
# Pine Lake Park
# Portola
# Potrero Hill
# Presidio
# Presidio Heights
# Russian Hill
# Saint Francis Wood
# Couldn't get venues from: Sea Cliff
# Silver Terrace
# South of Market
# Stonestown
# Sunnyside
# Telegraph Hill
# Twin Peaks
# Couldn't get venues from: Van Ness
# Civic Center
# Visitacion Valley
# West Portal
# Western Addition
# Westwood Highlands
# Westwood Park
# Lincoln Park
# Sherwood Forest
# Couldn't get venues from: Tenderloin
# Central Waterfront
# Dogpatch
# Candlestick Point
# Couldn't get venues from: Bayview Heights
# Couldn't get venues from: Little Hollywood
# Nob Hill

# %% [markdown]
# We now need to check our hyegiene dataframe in order to update the hygiene score and status of each of the restaurants we've gathered from the Foursquare API. Before that, we clean up the hygiene_df, keeping only the columns we need and the rows that contain values.

# %%
hygiene_df.columns
# Out:
# Index(['business_id', 'business_name', 'business_address', 'business_city',
#        'business_state', 'business_phone_number', 'inspection_id',
#        'inspection_date', 'inspection_type', 'business_postal_code',
#        'inspection_score', 'violation_id', 'violation_description',
#        'risk_category', 'business_latitude', 'business_longitude',
#        'business_location', ':@computed_region_fyvs_ahh9',
#        ':@computed_region_p5aj_wyqh', ':@computed_region_rxqg_mtj9',
#        ':@computed_region_yftq_j783', ':@computed_region_bh8s_q3mv',
#        ':@computed_region_ajp5_b2md'],
#       dtype='object')

# %%
hygiene_df=hygiene_df[['business_name','business_address','inspection_date', 'inspection_type','violation_description', 'risk_category','inspection_score' ]]
hygiene_df = hygiene_df[hygiene_df['inspection_score'].notna()]
hygiene_df
# Out:
#                              business_name     business_address  \
# 1                               BREADBELLY      1408 Clement St
# 7                             Fools Errand  639 Divisadero St A
# 8                                   MoBowL          428 11th St
# 11                                VICTOR'S      210 TOWNSEND St
# 12             New Garden Restaurant, Inc.        716 Kearny St
# ...                                    ...                  ...
# 53967                7 Eleven #2366-35722A      4850 Geary Blvd
# 53968                      Snowbird Coffee       1352 A 9th Ave
# 53969                      Buffalo Kitchen       107 Leland Ave
# 53970                            BUNN MIKE       300 DE HARO ST
# 53971  City Discount Meat & Grocery Market      2298 Mission St
#
#                inspection_date        inspection_type  \
# 1      2019-07-25T00:00:00.000  Routine - Unscheduled
# 7      2019-03-27T00:00:00.000  Routine - Unscheduled
# 8      2017-04-29T00:00:00.000  Routine - Unscheduled
# 11     2018-10-30T00:00:00.000  Routine - Unscheduled
# 12     2019-04-01T00:00:00.000  Routine - Unscheduled
# ...                        ...                    ...
# 53967  2018-09-19T00:00:00.000  Routine - Unscheduled
# 53968  2019-04-11T00:00:00.000  Routine - Unscheduled
# 53969  2019-04-17T00:00:00.000  Routine - Unscheduled
# 53970  2019-03-21T00:00:00.000  Routine - Unscheduled
# 53971  2019-04-18T00:00:00.000  Routine - Unscheduled
#
#                                    violation_description  risk_category  \
# 1      Inadequately cleaned or sanitized food contact...  Moderate Risk
# 7      Inadequately cleaned or sanitized food contact...  Moderate Risk
# 8                 Moderate risk food holding temperature  Moderate Risk
# 11     Improper storage use or identification of toxi...       Low Risk
# 12                        Improper or defective plumbing       Low Risk
# ...                                                  ...            ...
# 53967  Inadequate and inaccessible handwashing facili...  Moderate Risk
# 53968  Wiping cloths not clean or properly stored or ...       Low Risk
# 53969             Foods not protected from contamination  Moderate Risk
# 53970  Inadequate and inaccessible handwashing facili...  Moderate Risk
# 53971        Unclean or unsanitary food contact surfaces      High Risk
#
#       inspection_score
# 1                   96
# 7                   84
# 8                   94
# 11                  71
# 12                  85
# ...                ...
# 53967               84
# 53968               94
# 53969               75
# 53970               84
# 53971               83
#
# [39541 rows x 7 columns]

# %% [markdown]
# Now we can Map out the locations of each restaurant!

# %%
hygiene_df=hygiene_df.sort_values('inspection_date', ascending=False).drop_duplicates(subset='business_name', keep='first')
hygiene_df
# Out:
#                      business_name        business_address  \
# 3788                  Frisco Fried            5176 03rd St
# 6775            GENEVA STEAK HOUSE         5130 MISSION ST
# 1041                 Tokyo Express   160 Spear St Lobby ID
# 3732              5A5 Steak Lounge          244 Jackson St
# 2600    SHERIDAN ELEMENTARY SCHOOL         431 CAPITOL Ave
# ...                            ...                     ...
# 28072  Sally's Restaurant and Deli     300 De Haro St #332
# 30846            Way To Life Foods  1 United Nations Plaza
# 29937              Hey Hey Gourmet  1 United Nations Plaza
# 26965          Christine's Sausage  1 United Nations Plaza
# 36264                  CATER THYME    1 UNITED NATIONS Plz
#
#                inspection_date        inspection_type  \
# 3788   2019-10-03T00:00:00.000  Routine - Unscheduled
# 6775   2019-10-03T00:00:00.000  Routine - Unscheduled
# 1041   2019-10-03T00:00:00.000  Routine - Unscheduled
# 3732   2019-10-03T00:00:00.000  Routine - Unscheduled
# 2600   2019-10-03T00:00:00.000  Routine - Unscheduled
# ...                        ...                    ...
# 28072  2016-10-06T00:00:00.000  Routine - Unscheduled
# 30846  2016-10-05T00:00:00.000  Routine - Unscheduled
# 29937  2016-10-05T00:00:00.000  Routine - Unscheduled
# 26965  2016-10-05T00:00:00.000  Routine - Unscheduled
# 36264  2016-10-05T00:00:00.000  Routine - Unscheduled
#
#                                    violation_description  risk_category  \
# 3788        Unclean or degraded floors walls or ceilings       Low Risk
# 6775                            Improper thawing methods  Moderate Risk
# 1041                  High risk food holding temperature      High Risk
# 3732           Noncompliance with HAACP plan or variance  Moderate Risk
# 2600   Inadequate and inaccessible handwashing facili...  Moderate Risk
# ...                                                  ...            ...
# 28072             Moderate risk food holding temperature  Moderate Risk
# 30846                                                NaN            NaN
# 29937                                                NaN            NaN
# 26965                                                NaN            NaN
# 36264                                                NaN            NaN
#
#       inspection_score
# 3788                92
# 6775                92
# 1041                87
# 3732                81
# 2600                92
# ...                ...
# 28072               71
# 30846              100
# 29937              100
# 26965              100
# 36264              100
#
# [5277 rows x 7 columns]

# %%
sf_venues=fpd.fuzzy_merge(sf_venues, hygiene_df,
                        keep='all',
                        left_on=['Venue'],
                        right_on=['business_name'],
                        method='metaphone',
                        ignore_nonalpha=True,
                        ignore_nonlatin=True,
                        ignore_case=True,
                        join='inner')

sf_venues
# Out:
#      Neighbourhood                     Venue  Venue_Latitude  Venue_Longitude  \
# 0     Alamo Square         Little Star Pizza       37.777489      -122.438281
# 1     Alamo Square     Brenda's Meat & Three       37.778265      -122.438584
# 2     Alamo Square                  The Mill       37.776425      -122.437970
# 3     Alamo Square           Jane the Bakery       37.783797      -122.434283
# 4     Alamo Square              The Progress       37.783745      -122.432972
# ...            ...                       ...             ...              ...
# 5024      Nob Hill           Osso Steakhouse       37.791447      -122.413530
# 5025      Nob Hill             Batter Bakery       37.789551      -122.420776
# 5026      Nob Hill  Nobhill Pizza & Shawerma       37.790767      -122.419747
# 5027      Nob Hill        Kasa Indian Eatery       37.789655      -122.420449
# 5028      Nob Hill   Golden Horse Restaurant       37.790860      -122.417340
#
#                        Venue_Category             business_name  \
# 0                         Pizza Place         Little Star Pizza
# 1     Southern / Soul Food Restaurant      Brendas Meat & Three
# 2                              Bakery                  The Mill
# 3                              Bakery           Jane the Bakery
# 4                 American Restaurant              The Progress
# ...                               ...                       ...
# 5024                       Steakhouse           Osso Steakhouse
# 5025                           Bakery             Batter Bakery
# 5026                      Pizza Place  Nobhill Pizza & Shawerma
# 5027                Indian Restaurant        Kasa Indian Eatery
# 5028               Chinese Restaurant   Golden Horse Restaurant
#
#         business_address          inspection_date        inspection_type  \
# 0         846 Divisadero  2018-04-24T00:00:00.000  Routine - Unscheduled
# 1      919 DIVISADERO ST  2019-03-13T00:00:00.000  Routine - Unscheduled
# 2      736 DIVISADERO St  2019-04-11T00:00:00.000  Routine - Unscheduled
# 3        1875 Geary Blvd  2019-07-03T00:00:00.000  Routine - Unscheduled
# 4       1525 Fillmore St  2019-02-14T00:00:00.000  Routine - Unscheduled
# ...                  ...                      ...                    ...
# 5024  1177 California St  2019-06-03T00:00:00.000  Routine - Unscheduled
# 5025        1517 Pine St  2018-08-21T00:00:00.000  Routine - Unscheduled
# 5026  1534 California St  2019-09-23T00:00:00.000  Routine - Unscheduled
# 5027        4001 18th St  2019-09-23T00:00:00.000  Routine - Unscheduled
# 5028        1060 Hyde St  2018-01-23T00:00:00.000  Routine - Unscheduled
#
#                                   violation_description  risk_category  \
# 0                                                   NaN            NaN
# 1     Inadequately cleaned or sanitized food contact...  Moderate Risk
# 2                      Moderate risk vermin infestation  Moderate Risk
# 3      Improper storage of equipment utensils or linens       Low Risk
# 4     Inadequately cleaned or sanitized food contact...  Moderate Risk
# ...                                                 ...            ...
# 5024  Inadequately cleaned or sanitized food contact...  Moderate Risk
# 5025  Wiping cloths not clean or properly stored or ...       Low Risk
# 5026                 High risk food holding temperature      High Risk
# 5027                        Low risk vermin infestation       Low Risk
# 5028                   Moderate risk vermin infestation  Moderate Risk
#
#      inspection_score
# 0                 100
# 1                  92
# 2                  88
# 3                  87
# 4                  90
# ...               ...
# 5024               96
# 5025               98
# 5026               93
# 5027               86
# 5028               79
#
# [5029 rows x 12 columns]

# %%
sf_center = [37.7749, -122.4194]
sf_map = folium.Map(location=sf_center, zoom_start=13)
folium.Marker(sf_center, popup='City Center').add_to(sf_map)
for name, lat, lng in zip(sf_venues.Venue, sf_venues.Venue_Latitude, sf_venues.Venue_Longitude):
    folium.CircleMarker([lat, lng], radius=3, color=color, fill=True, fill_color=color, fill_opacity=1).add_to(sf_map)
    color = 'blue'
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
